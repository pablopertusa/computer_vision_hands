# %% [markdown]
# # Modelo MLP

# %% [markdown]
# ## Funciones procesado

# %%
import os
import numpy as np
import cv2
from sklearn.cluster import MiniBatchKMeans
from tensorflow import keras
from sklearn.preprocessing import LabelEncoder

# %%
def leer_imagenes_rgb(dataset_path):
    jpgFiles = [fJPG for fJPG in os.listdir(dataset_path) if fJPG.endswith('.jpg')]
    bufferImages = []
    y = []

    # Extraer 50 patches aleatorios de cada imagen
    for filename in jpgFiles:
        img_path = os.path.join(dataset_path, filename)
        label = filename.split('.')[0][-2:]
        y.append(label)
        img = cv2.imread(img_path)
        # Convertir imagen de BGR a RGB
        img_color = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
        resized_img = cv2.resize(img_color, (150, 150), interpolation=cv2.INTER_AREA)
        bufferImages.append(resized_img)
    
    bufferImages = np.array(bufferImages)

    return bufferImages, y

# %%
from sklearn.base import BaseEstimator, TransformerMixin


class CustomBoVWPreprocessorSamePatches(BaseEstimator, TransformerMixin):
    def __init__(self, patchSize=10, nClusters = 81, max_patches=50, norm = False):
        self.patchSize = patchSize
        self.nClusters = nClusters
        self.max_patches = max_patches
        self.norm = norm   
    
    def extract_centric_patches(self, img, patch_size, num_patches, seed=42):
        assert img.shape[0] == 150 and img.shape[1] == 150, "La imagen debe tener resolución 150x150."
        assert patch_size > 0, "El tamaño del patch debe ser mayor que 0."
        assert patch_size * num_patches <= 150 * 150, "Demasiados patches para esta resolución."
        
        # Calcular la cuadrícula de celdas no superpuestas
        grid_rows = 150 // patch_size
        grid_cols = 150 // patch_size
        total_cells = grid_rows * grid_cols

        assert num_patches <= total_cells, "Demasiados patches para el tamaño del patch y la resolución de la imagen."
        
        # Generar las posiciones de la cuadrícula
        all_positions = [(i * patch_size, j * patch_size) for i in range(grid_rows) for j in range(grid_cols)]

        # Calcular las distancias de las celdas al centro de la imagen
        center = (150 // 2, 150 // 2)
        distances = [
            np.sqrt((row + patch_size // 2 - center[0])**2 + (col + patch_size // 2 - center[1])**2)
            for row, col in all_positions
        ]

        # Ordenar las posiciones por cercanía al centro
        sorted_positions = [pos for _, pos in sorted(zip(distances, all_positions))]
        
        # Seleccionar los patches más céntricos
        np.random.seed(seed)
        selected_positions = sorted_positions[:num_patches]
        
        # Extraer los patches en las posiciones seleccionadas
        patches = [img[row:row + patch_size, col:col + patch_size] for row, col in selected_positions]

        #self.visualize_disjoint_patches(img, patches, selected_positions, patch_size)
        
        return np.array(patches)


    def bovw(self, images, patchSize, nClusters, maxPatches):
        bufferData = []
        for i in images:
            #resized_img = cv2.resize(i, (150, 150), interpolation=cv2.INTER_AREA)
            patches = self.extract_centric_patches(i, patchSize, num_patches=maxPatches, seed=27) # shape = (maxPatches,5,5,3)
            patches = np.reshape(patches, (len(patches), -1)) # shape = (maxPatches,75)
            bufferData.append(patches)
        dataIm = np.concatenate(bufferData, axis=0) # shape = (200*maxPatches,75)  n patches x 200 imágenes
        dataIm = dataIm.astype(float)
        dataIm -= np.mean(dataIm, axis=0)
        dataIm /= np.std(dataIm, axis=0)
        kmeans = MiniBatchKMeans(n_clusters=nClusters, random_state=27, verbose=False)
        kmeans.partial_fit(dataIm)

        X = np.reshape(kmeans.labels_ , (len(images),maxPatches)) # Indice de cluster de cada patch. shape = (200,maxPatches)
        resul = [np.bincount(row, minlength=nClusters) for row in X]
        resul = np.array(resul)

        if self.norm:
            contador_palabras = np.zeros((nClusters,))
            for p in range(nClusters):
                for i in resul[:,p]:
                    if i > 0:
                        contador_palabras[p] += 1
            for p in range(nClusters):
                for imagen in resul:
                    imagen[p] = imagen[p] * np.log(len(images)/(contador_palabras[p]+0.001)) # Actualizamos el valor por el logaritmo del cociente entre N y el número de imágenes en las que aparece esa palabra

        return resul

    def transform(self, images):
        return self.bovw(images, self.patchSize, self.nClusters, self.max_patches)  # Devuelve los datos preprocesados

# %% [markdown]
# ## Datos

# %%
path = '/home/pablo/Desktop/tercero/mdp/trabajo/HANDS'

imagenes, labels = leer_imagenes_rgb(path)

# %%
bovw = CustomBoVWPreprocessorSamePatches()
X = bovw.transform(imagenes)

# %%
from keras.utils import to_categorical

encoder = LabelEncoder()
labels_cat = encoder.fit_transform(labels)
y = to_categorical(labels_cat, 4) #to_categorical funciona solo con las clases como números

# %% [markdown]
# ## Creación modelo

# %%
from sklearn.model_selection import train_test_split
from keras.optimizers import SGD
from keras import Sequential
from keras.layers import Dense, Input, Dropout

# %%
model = Sequential()

model.add(Input(shape=(81,)))
model.add(Dense(512, activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(1024, activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(256, activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(64, activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(16, activation='relu'))
model.add(Dense(4, activation='softmax'))


model.compile(optimizer = SGD(), loss='categorical_crossentropy',
                metrics=['accuracy'])

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
callback = keras.callbacks.EarlyStopping(monitor='loss', min_delta=0.01, patience=5)

# %%
history = model.fit(X_train, y_train, epochs=200, batch_size=128, callbacks=[callback])
# Out:
# Epoch 1/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 4s 23ms/step - accuracy: 0.2666 - loss: 1.4260
# Epoch 2/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 663us/step - accuracy: 0.3020 - loss: 1.3812
# Epoch 3/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 648us/step - accuracy: 0.3485 - loss: 1.3533
# Epoch 4/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 685us/step - accuracy: 0.4014 - loss: 1.2975
# Epoch 5/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 638us/step - accuracy: 0.4340 - loss: 1.2297
# Epoch 6/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 654us/step - accuracy: 0.4505 - loss: 1.1768
# Epoch 7/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 625us/step - accuracy: 0.4461 - loss: 1.1554
# Epoch 8/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 659us/step - accuracy: 0.4647 - loss: 1.1367
# Epoch 9/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 666us/step - accuracy: 0.4750 - loss: 1.1279
# Epoch 10/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 619us/step - accuracy: 0.4904 - loss: 1.1001
# Epoch 11/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 636us/step - accuracy: 0.5009 - loss: 1.0661
# Epoch 12/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 694us/step - accuracy: 0.5204 - loss: 1.0626
# Epoch 13/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 615us/step - accuracy: 0.5208 - loss: 1.0563
# Epoch 14/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 628us/step - accuracy: 0.5283 - loss: 1.0349
# Epoch 15/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 681us/step - accuracy: 0.5564 - loss: 0.9972
# Epoch 16/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 635us/step - accuracy: 0.5515 - loss: 1.0031
# Epoch 17/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 658us/step - accuracy: 0.5470 - loss: 1.0061
# Epoch 18/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 660us/step - accuracy: 0.5732 - loss: 0.9797
# Epoch 19/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 666us/step - accuracy: 0.5723 - loss: 0.9626
# Epoch 20/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 663us/step - accuracy: 0.5787 - loss: 0.9558
# Epoch 21/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 682us/step - accuracy: 0.5783 - loss: 0.9454
# Epoch 22/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 636us/step - accuracy: 0.5983 - loss: 0.9309
# Epoch 23/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 655us/step - accuracy: 0.5990 - loss: 0.9237
# Epoch 24/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 613us/step - accuracy: 0.6245 - loss: 0.9064
# Epoch 25/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 635us/step - accuracy: 0.6102 - loss: 0.9085
# Epoch 26/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 623us/step - accuracy: 0.6138 - loss: 0.8956
# Epoch 27/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 641us/step - accuracy: 0.6315 - loss: 0.8797
# Epoch 28/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 662us/step - accuracy: 0.6191 - loss: 0.8991
# Epoch 29/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 639us/step - accuracy: 0.6318 - loss: 0.8804
# Epoch 30/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 682us/step - accuracy: 0.6271 - loss: 0.8816
# Epoch 31/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 628us/step - accuracy: 0.6293 - loss: 0.8769
# Epoch 32/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 647us/step - accuracy: 0.6372 - loss: 0.8520
# Epoch 33/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 631us/step - accuracy: 0.6402 - loss: 0.8483
# Epoch 34/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 623us/step - accuracy: 0.6470 - loss: 0.8430
# Epoch 35/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 630us/step - accuracy: 0.6467 - loss: 0.8228
# Epoch 36/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 836us/step - accuracy: 0.6615 - loss: 0.8255
# Epoch 37/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 602us/step - accuracy: 0.6545 - loss: 0.8330
# Epoch 38/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 596us/step - accuracy: 0.6560 - loss: 0.8193
# Epoch 39/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 620us/step - accuracy: 0.6585 - loss: 0.8186
# Epoch 40/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 640us/step - accuracy: 0.6537 - loss: 0.8106
# Epoch 41/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 612us/step - accuracy: 0.6700 - loss: 0.7948
# Epoch 42/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 596us/step - accuracy: 0.6736 - loss: 0.7877
# Epoch 43/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 678us/step - accuracy: 0.6709 - loss: 0.7816
# Epoch 44/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 634us/step - accuracy: 0.6853 - loss: 0.7755
# Epoch 45/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 620us/step - accuracy: 0.6927 - loss: 0.7560
# Epoch 46/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 623us/step - accuracy: 0.6780 - loss: 0.7742
# Epoch 47/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 622us/step - accuracy: 0.6829 - loss: 0.7605
# Epoch 48/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 668us/step - accuracy: 0.6881 - loss: 0.7401
# Epoch 49/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 608us/step - accuracy: 0.6949 - loss: 0.7445
# Epoch 50/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 653us/step - accuracy: 0.7002 - loss: 0.7367
# Epoch 51/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 618us/step - accuracy: 0.6934 - loss: 0.7362
# Epoch 52/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 606us/step - accuracy: 0.7091 - loss: 0.7182
# Epoch 53/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 613us/step - accuracy: 0.7033 - loss: 0.7139
# Epoch 54/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 639us/step - accuracy: 0.7153 - loss: 0.6994
# Epoch 55/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 687us/step - accuracy: 0.7073 - loss: 0.7161
# Epoch 56/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 612us/step - accuracy: 0.7118 - loss: 0.6934
# Epoch 57/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 637us/step - accuracy: 0.7275 - loss: 0.6778
# Epoch 58/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 611us/step - accuracy: 0.7231 - loss: 0.6872
# Epoch 59/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 635us/step - accuracy: 0.7234 - loss: 0.6798
# Epoch 60/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 628us/step - accuracy: 0.7193 - loss: 0.6793
# Epoch 61/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 597us/step - accuracy: 0.7260 - loss: 0.6630
# Epoch 62/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 633us/step - accuracy: 0.7306 - loss: 0.6576
# Epoch 63/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 615us/step - accuracy: 0.7368 - loss: 0.6738
# Epoch 64/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 596us/step - accuracy: 0.7245 - loss: 0.6716
# Epoch 65/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 619us/step - accuracy: 0.7333 - loss: 0.6492
# Epoch 66/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 628us/step - accuracy: 0.7318 - loss: 0.6542
# Epoch 67/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 617us/step - accuracy: 0.7551 - loss: 0.6239
# Epoch 68/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 628us/step - accuracy: 0.7412 - loss: 0.6473
# Epoch 69/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 640us/step - accuracy: 0.7419 - loss: 0.6310
# Epoch 70/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 665us/step - accuracy: 0.7484 - loss: 0.6326
# Epoch 71/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 640us/step - accuracy: 0.7462 - loss: 0.6205
# Epoch 72/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 654us/step - accuracy: 0.7613 - loss: 0.6090
# Epoch 73/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 633us/step - accuracy: 0.7544 - loss: 0.6137
# Epoch 74/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 642us/step - accuracy: 0.7594 - loss: 0.5883
# Epoch 75/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 624us/step - accuracy: 0.7619 - loss: 0.5884
# Epoch 76/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 640us/step - accuracy: 0.7673 - loss: 0.5893
# Epoch 77/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 820us/step - accuracy: 0.7706 - loss: 0.5795
# Epoch 78/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 610us/step - accuracy: 0.7829 - loss: 0.5597
# Epoch 79/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 644us/step - accuracy: 0.7609 - loss: 0.5921
# Epoch 80/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 685us/step - accuracy: 0.7683 - loss: 0.5736
# Epoch 81/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 628us/step - accuracy: 0.7731 - loss: 0.5579
# Epoch 82/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 670us/step - accuracy: 0.7769 - loss: 0.5560
# Epoch 83/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 624us/step - accuracy: 0.7835 - loss: 0.5572
# Epoch 84/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 651us/step - accuracy: 0.7839 - loss: 0.5445
# Epoch 85/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 666us/step - accuracy: 0.7874 - loss: 0.5471
# Epoch 86/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 657us/step - accuracy: 0.7930 - loss: 0.5354
# Epoch 87/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 603us/step - accuracy: 0.7851 - loss: 0.5476
# Epoch 88/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 661us/step - accuracy: 0.8022 - loss: 0.5224
# Epoch 89/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 623us/step - accuracy: 0.7907 - loss: 0.5304
# Epoch 90/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 617us/step - accuracy: 0.7981 - loss: 0.5032
# Epoch 91/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 608us/step - accuracy: 0.8021 - loss: 0.5101
# Epoch 92/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 634us/step - accuracy: 0.8031 - loss: 0.4968
# Epoch 93/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 699us/step - accuracy: 0.8020 - loss: 0.5094
# Epoch 94/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 625us/step - accuracy: 0.7989 - loss: 0.5005
# Epoch 95/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 642us/step - accuracy: 0.8032 - loss: 0.5009
# Epoch 96/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 628us/step - accuracy: 0.8086 - loss: 0.4856
# Epoch 97/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 615us/step - accuracy: 0.8100 - loss: 0.4777
# Epoch 98/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 634us/step - accuracy: 0.8100 - loss: 0.4872
# Epoch 99/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 636us/step - accuracy: 0.8146 - loss: 0.4731
# Epoch 100/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 621us/step - accuracy: 0.8257 - loss: 0.4634
# Epoch 101/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 643us/step - accuracy: 0.8200 - loss: 0.4562
# Epoch 102/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 595us/step - accuracy: 0.8263 - loss: 0.4595
# Epoch 103/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 648us/step - accuracy: 0.8196 - loss: 0.4698
# Epoch 104/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 628us/step - accuracy: 0.8254 - loss: 0.4576
# Epoch 105/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 677us/step - accuracy: 0.8312 - loss: 0.4469
# Epoch 106/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 675us/step - accuracy: 0.8293 - loss: 0.4399
# Epoch 107/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 631us/step - accuracy: 0.8269 - loss: 0.4445
# Epoch 108/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 610us/step - accuracy: 0.8405 - loss: 0.4212
# Epoch 109/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 631us/step - accuracy: 0.8373 - loss: 0.4200
# Epoch 110/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 760us/step - accuracy: 0.8283 - loss: 0.4407
# Epoch 111/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 633us/step - accuracy: 0.8309 - loss: 0.4303
# Epoch 112/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 612us/step - accuracy: 0.8352 - loss: 0.4218
# Epoch 113/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 620us/step - accuracy: 0.8359 - loss: 0.4309
# Epoch 114/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 639us/step - accuracy: 0.8464 - loss: 0.4151
# Epoch 115/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 613us/step - accuracy: 0.8373 - loss: 0.4215
# Epoch 116/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 637us/step - accuracy: 0.8430 - loss: 0.4100
# Epoch 117/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 625us/step - accuracy: 0.8412 - loss: 0.4125
# Epoch 118/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 631us/step - accuracy: 0.8480 - loss: 0.3896
# Epoch 119/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 696us/step - accuracy: 0.8417 - loss: 0.4129
# Epoch 120/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 640us/step - accuracy: 0.8546 - loss: 0.3876
# Epoch 121/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 621us/step - accuracy: 0.8648 - loss: 0.3619
# Epoch 122/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 631us/step - accuracy: 0.8659 - loss: 0.3621
# Epoch 123/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 621us/step - accuracy: 0.8472 - loss: 0.3903
# Epoch 124/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 610us/step - accuracy: 0.8528 - loss: 0.3742
# Epoch 125/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 613us/step - accuracy: 0.8591 - loss: 0.3703
# Epoch 126/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 645us/step - accuracy: 0.8641 - loss: 0.3595
# Epoch 127/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 612us/step - accuracy: 0.8625 - loss: 0.3665
# Epoch 128/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 619us/step - accuracy: 0.8577 - loss: 0.3695
# Epoch 129/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 670us/step - accuracy: 0.8677 - loss: 0.3524
# Epoch 130/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 646us/step - accuracy: 0.8679 - loss: 0.3554
# Epoch 131/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 592us/step - accuracy: 0.8650 - loss: 0.3483
# Epoch 132/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 693us/step - accuracy: 0.8688 - loss: 0.3378
# Epoch 133/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 614us/step - accuracy: 0.8691 - loss: 0.3416
# Epoch 134/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 636us/step - accuracy: 0.8724 - loss: 0.3364
# Epoch 135/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 663us/step - accuracy: 0.8752 - loss: 0.3247
# Epoch 136/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 740us/step - accuracy: 0.8756 - loss: 0.3168
# Epoch 137/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 634us/step - accuracy: 0.8707 - loss: 0.3206
# Epoch 138/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 641us/step - accuracy: 0.8757 - loss: 0.3282
# Epoch 139/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 675us/step - accuracy: 0.8766 - loss: 0.3239
# Epoch 140/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 599us/step - accuracy: 0.8733 - loss: 0.3255

# %%
loss, accuracy = model.evaluate(X_test, y_test, verbose=0)
print(f"Test Accuracy: {accuracy:.4f}")
# Out:
# Test Accuracy: 0.8020

# %%
model.save('modelo/model.keras')
